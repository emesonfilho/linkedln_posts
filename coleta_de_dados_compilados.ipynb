# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web

import matplotlib.pyplot as plt
import investpy as inv

from scipy import stats

import yfinance as yf

# %% [markdown]
# ### Aqui tu pode pegar os dados de negociação das empresas (puxando do yahoo)
#
# * As Opções são: Hig / Low / Open / Close / Volume / Adj Close
#
# * Caso seja mais de uma ação, só é possível pegar um por vez, no primeiro exemplo, pegando o preço ajustado de fechamento, e no segundo, pegando todas as informações de apenas um ativo.

# %%
ativos = ['PETR3.SA', 'PETR4.SA', 'VVAR3.SA', 'BBDC4.SA', 'VALE3.SA']
dados = pd.DataFrame()

for a in ativos:
    dados[a] = wb.DataReader(a, data_source = 'yahoo', start = '2018-01-01')['Adj Close']

# %%
dados
# Out:
#              PETR3.SA   PETR4.SA   VVAR3.SA   BBDC4.SA   VALE3.SA
# Date
# 2018-01-02  16.250778  15.353477   7.698611  23.571886  39.060638
# 2018-01-03  16.457075  15.492632   7.738552  23.679100  38.826576
# 2018-01-04  16.597738  15.520465   7.798464  24.067608  38.985741
# 2018-01-05  16.729017  15.613236   7.548833  24.203918  39.594303
# 2018-01-08  16.991579  15.798776   7.678641  24.197069  40.474384
# ...               ...        ...        ...        ...        ...
# 2020-08-25  23.430000  22.870001  20.700001  21.170000  61.619999
# 2020-08-26  22.760000  22.219999  20.290001  20.730000  61.750000
# 2020-08-27  22.650000  22.150000  20.360001  21.040001  60.790001
# 2020-08-28  23.110001  22.540001  20.219999  21.469999  61.099998
# 2020-08-31  22.320000  21.889999  20.500000  20.740000  59.680000
#
# [658 rows x 5 columns]

# %%
dados = wb.DataReader("ITUB4.SA", data_source = 'yahoo', start = '2018-01-01')

# %%
dados
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2018-01-02  29.253300  28.533300  28.533300  29.253300  16650900.0  25.651060
# 2018-01-03  29.559999  29.046700  29.266701  29.453300  22295700.0  25.826433
# 2018-01-04  30.200001  29.500000  29.500000  30.066700  23222550.0  26.364296
# 2018-01-05  30.213301  29.733299  30.080000  30.153299  15717450.0  26.440237
# 2018-01-08  30.213301  29.853300  30.040001  30.053301  12708150.0  26.352549
# ...               ...        ...        ...        ...         ...        ...
# 2020-08-25  24.700001  24.120001  24.639999  24.299999  32007000.0  24.284521
# 2020-08-26  24.360001  23.510000  24.299999  23.790001  30643300.0  23.774849
# 2020-08-27  24.500000  23.799999  23.889999  24.180000  35293000.0  24.164598
# 2020-08-28  24.559999  24.150000  24.299999  24.430000  56136100.0  24.414440
# 2020-08-31  24.290001  23.549999  24.170000  23.549999  45045400.0  23.535000
#
# [658 rows x 6 columns]

# %% [markdown]
# ### Aqui tu pode pegar os dados de negociação das empresas (puxando do yahoo)
#
# * As Opções são: Open / High / Low / Close / Volume / Currency
#
# * Caso seja mais de uma ação, só é possível pegar um por vez, no primeiro exemplo, pegando o preço ajustado de fechamento, e no segundo, pegando todas as informações de apenas um ativo.

# %%
papeis = ['PETR3', 'PETR4', 'VVAR3', 'BBDC4', 'VALE3']
PAPEIS_ANALISADOS = pd.DataFrame()
for papel in papeis:
    PAPEIS_ANALISADOS[papel] = inv.get_stock_historical_data(papel, 'brazil', 
                                           from_date= '01/01/2015', 
                                           to_date='31/12/2020')['Close']

# %%
PAPEIS_ANALISADOS
# Out:
#             PETR3  PETR4  VVAR3  BBDC4  VALE3
# Date
# 2015-01-01   8.91   8.98    NaN  14.82  20.64
# 2015-01-04   8.19   8.26    NaN  14.84  20.33
# 2015-01-05   7.98   7.99    NaN  15.33  21.15
# 2015-01-06   8.37   8.32   7.13  15.94  21.93
# 2015-01-07   8.93   8.81    NaN  16.02  22.16
# ...           ...    ...    ...    ...    ...
# 2020-08-24  23.43  22.87  20.70  21.17  61.62
# 2020-08-25  22.76  22.22  20.29  20.73  61.75
# 2020-08-26  22.65  22.15  20.36  21.04  60.79
# 2020-08-27  23.11  22.54  20.22  21.47  61.10
# 2020-08-30  22.32  21.89  20.50  20.74  59.68
#
# [1401 rows x 5 columns]

# %%
PAPEIS_ANALISADOS = inv.get_stock_historical_data("ITUB4", 'brazil',
                                                  from_date= '01/01/2015', 
                                                  to_date='31/12/2020')

# %%
PAPEIS_ANALISADOS
# Out:
#              Open   High    Low  Close    Volume Currency
# Date
# 2015-01-01  14.54  14.78  14.23  14.36  20418918      BRL
# 2015-01-04  14.14  14.58  14.02  14.43  22998030      BRL
# 2015-01-05  14.43  14.67  14.28  14.67  26907538      BRL
# 2015-01-06  14.86  15.43  14.86  15.20  22903106      BRL
# 2015-01-07  15.28  15.49  14.95  15.43  20831284      BRL
# ...           ...    ...    ...    ...       ...      ...
# 2020-08-24  24.67  24.70  24.12  24.30  30865600      BRL
# 2020-08-25  24.28  24.36  23.52  23.79  30400900      BRL
# 2020-08-26  23.83  24.50  23.80  24.18  34844500      BRL
# 2020-08-27  24.32  24.56  24.17  24.43  54751600      BRL
# 2020-08-30  24.23  24.29  23.55  23.55  33045300      BRL
#
# [1401 rows x 6 columns]

# %% [markdown]
# ### Pegando os dados do Banco Central
#
# * IPCA: 433
#
# * Metas para a inflação: 13521
#
# * SELIC a.d: 11
#
# * SELIC meta (definida pelo copom) a.a: 432
#
# * SELIC anualizada na base 252: 1178
#
# ### Sobre as moedas
#
# * Taxa de câmbio - Livre - Euro (venda): 21619
#
# * Taxa de câmbio - Livre - Euro (compra): 21620
#
# * Taxa de câmbio - Livre - Dólar americano (venda) : 1
#
# * Taxa de câmbio - Flutuante - Dólar turismo - Venda: 3
#
# ### Para pegar mais alguma informação basta ir em:
#
# > https://www3.bcb.gov.br/sgspub/localizarseries/localizarSeries.do?method=prepararTelaLocalizarSeries

# %%
def consulta_bc(cod_bcb):
    url = f'http://api.bcb.gov.br/dados/serie/bcdata.sgs.{cod_bcb}/dados?formato=json'
    df = pd.read_json(url)
    df['data'] = pd.to_datetime(df['data'], dayfirst=True)
    df.set_index('data', inplace = True)
    return df

# %%
IPCA = consulta_bc(433)

# %%
IPCA
# Out:
#             valor
# data
# 1980-01-01   6.62
# 1980-02-01   4.62
# 1980-03-01   6.04
# 1980-04-01   5.29
# 1980-05-01   5.70
# ...           ...
# 2020-03-01   0.07
# 2020-04-01  -0.31
# 2020-05-01  -0.38
# 2020-06-01   0.26
# 2020-07-01   0.36
#
# [487 rows x 1 columns]

# %%
plt.rcParams['figure.figsize'] = (15, 6)
plt.plot(IPCA)

# %% [markdown]
# ### Sobre os dados dos tesouros
#
# > https://www.tesourotransparente.gov.br/ckan/dataset

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
def busca_titulos_tesouro_direto():
  url = 'https://www.tesourotransparente.gov.br/ckan/dataset/df56aa42-484a-4a59-8184-7676580c81e3/resource/796d2059-14e9-44e3-80c9-2d9e30b405c1/download/PrecoTaxaTesouroDireto.csv'
  df  = pd.read_csv(url, sep=';', decimal=',')
  df['Data Vencimento'] = pd.to_datetime(df['Data Vencimento'], dayfirst=True)
  df['Data Base']       = pd.to_datetime(df['Data Base'], dayfirst=True)
  multi_indice = pd.MultiIndex.from_frame(df.iloc[:, :3])
  df = df.set_index(multi_indice).iloc[: , 3:]  
  return df

# %%
def busca_vendas_tesouro():
  url = "https://www.tesourotransparente.gov.br/ckan/dataset/f0468ecc-ae97-4287-89c2-6d8139fb4343/resource/e5f90e3a-8f8d-4895-9c56-4bb2f7877920/download/VendasTesouroDireto.csv"
  df  = pd.read_csv(url, sep=';', decimal=',')
  df['Vencimento do Titulo'] = pd.to_datetime(df['Vencimento do Titulo'], dayfirst=True)
  df['Data Venda']       = pd.to_datetime(df['Data Venda'], dayfirst=True)
  multi_indice = pd.MultiIndex.from_frame(df.iloc[:, :3])
  df = df.set_index(multi_indice).iloc[: , 3:]  
  return df

# %%
def busca_recompras_tesouro():
  url = "https://www.tesourotransparente.gov.br/ckan/dataset/f30db6e4-6123-416c-b094-be8dfc823601/resource/30c2b3f5-6edd-499a-8514-062bfda0f61a/download/RecomprasTesouroDireto.csv"
  df  = pd.read_csv(url, sep=';', decimal=',')
  df['Vencimento do Titulo'] = pd.to_datetime(df['Vencimento do Titulo'], dayfirst=True)
  df['Data Resgate']       = pd.to_datetime(df['Data Resgate'], dayfirst=True)
  multi_indice = pd.MultiIndex.from_frame(df.iloc[:, :3])
  df = df.set_index(multi_indice).iloc[: , 3:]  
  return df

# %%
titulos = busca_titulos_tesouro_direto()
titulos.sort_index(inplace=True)
titulos
# Out:
#                                                                Taxa Compra Manha  \
# Tipo Titulo                        Data Vencimento Data Base
# Tesouro IGPM+ com Juros Semestrais 2005-07-01      2004-12-31               9.23
#                                                    2005-01-03               9.23
#                                                    2005-01-04               9.26
#                                                    2005-01-05               9.28
#                                                    2005-01-06               9.31
# ...                                                                          ...
# Tesouro Selic                      2025-03-01      2020-08-25               0.03
#                                                    2020-08-26               0.03
#                                                    2020-08-27               0.03
#                                                    2020-08-28               0.03
# ...

# %%
tipos_titulos = titulos.index.droplevel(level=1).droplevel(level=1).drop_duplicates().to_list()
tipos_titulos
# Out:
# ['Tesouro IGPM+ com Juros Semestrais',
#  'Tesouro IPCA+',
#  'Tesouro IPCA+ com Juros Semestrais',
#  'Tesouro Prefixado',
#  'Tesouro Prefixado com Juros Semestrais',
#  'Tesouro Selic']

# %%
selic2025 = titulos.loc[('Tesouro Selic', '2025-03-01')]
selic2025
# Out:
#             Taxa Compra Manha  Taxa Venda Manha  PU Compra Manha  \
# Data Base
# 2019-02-01               0.02              0.06          9926.99
# 2019-02-04               0.02              0.06          9929.43
# 2019-02-05               0.02              0.06          9931.88
# 2019-02-06               0.02              0.06          9934.34
# 2019-02-07               0.02              0.06          9936.79
# ...                       ...               ...              ...
# 2020-08-25               0.03              0.04         10673.59
# 2020-08-26               0.03              0.04         10674.44
# 2020-08-27               0.03              0.04         10675.20
# 2020-08-28               0.03              0.04         10676.02
# 2020-08-31               0.03              0.04         10676.79
#
#             PU Venda Manha  PU Base Manha
# Data Base
# 2019-02-01         9902.94        9900.45
# 2019-02-04         9905.40        9902.91
# ...

# %%
selic2025['PU Base Manha'].plot();

# %%
pre2023 = titulos.loc[('Tesouro Prefixado', '2023-01-01')]
pre2023
# Out:
#             Taxa Compra Manha  Taxa Venda Manha  PU Compra Manha  \
# Data Base
# 2016-01-26              16.59             16.65           346.72
# 2016-01-27              16.32             16.38           352.52
# 2016-01-28              16.42             16.48           350.65
# 2016-01-29              15.93             15.99           361.21
# 2016-02-01              15.89             15.95           362.28
# ...                       ...               ...              ...
# 2020-08-25               4.06              4.18           911.03
# 2020-08-26               4.09              4.21           910.56
# 2020-08-27               4.21              4.33           908.26
# 2020-08-28               4.16              4.28           909.42
# 2020-08-31               4.15              4.27           909.77
#
#             PU Venda Manha  PU Base Manha
# Data Base
# 2016-01-26          345.49         345.28
# 2016-01-27          351.27         351.06
# ...

# %%
(pre2023['Taxa Compra Manha'] / pre2023['Taxa Compra Manha'].iloc[0]).plot();
(pre2023['PU Compra Manha'] / pre2023['PU Compra Manha'].iloc[0]).plot();

# %% [markdown]
# ### Pegando os dados do banco central americano
#
# > fonte: https://fred.stlouisfed.org/

# %%
import plotly.express as px

# %%
# PIB
gdp = web.DataReader('GDP', 'fred', "2000-01-01" )
gdp
# Out:
#                   GDP
# DATE
# 2000-01-01  10002.857
# 2000-04-01  10247.679
# 2000-07-01  10319.825
# 2000-10-01  10439.025
# 2001-01-01  10472.879
# ...               ...
# 2019-04-01  21329.877
# 2019-07-01  21540.325
# 2019-10-01  21747.394
# 2020-01-01  21561.139
# 2020-04-01  19486.509
#
# [82 rows x 1 columns]

# %%
px.line(gdp, x=gdp.index, y='GDP')
# Out:
# <div>
#
#
#             <div id="b117a6c9-a64c-4ab7-b69e-4d5f9eae61a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b117a6c9-a64c-4ab7-b69e-4d5f9eae61a4")) {
#                     Plotly.newPlot(
#                         'b117a6c9-a64c-4ab7-b69e-4d5f9eae61a4',
# ...

# %%
# CPI (inflação)
cpi = web.DataReader('CPIAUCSL', 'fred', '2000-01-01')
cpi
# Out:
#             CPIAUCSL
# DATE
# 2000-01-01   169.300
# 2000-02-01   170.000
# 2000-03-01   171.000
# 2000-04-01   170.900
# 2000-05-01   171.200
# ...              ...
# 2020-03-01   257.953
# 2020-04-01   255.902
# 2020-05-01   255.768
# 2020-06-01   257.214
# 2020-07-01   258.723
#
# [247 rows x 1 columns]

# %%
px.bar(data_frame=cpi.pct_change()*100, x=cpi.index, y='CPIAUCSL', labels={'CPIAUCSL':'Inflação (%)'})
# Out:
# <div>
#
#
#             <div id="8f0f25f1-59bd-448e-97cb-68fc17e02b21" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f0f25f1-59bd-448e-97cb-68fc17e02b21")) {
#                     Plotly.newPlot(
#                         '8f0f25f1-59bd-448e-97cb-68fc17e02b21',
# ...

# %%
# Treasury Bonds
# 3 Meses
t3mo = web.DataReader('DGS3MO', 'fred', "2000-01-01")

# %%
px.line(data_frame=t3mo, x=t3mo.index, y='DGS3MO')
# Out:
# <div>
#
#
#             <div id="8eef2047-3b82-46b9-991b-a56f5ecb91fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8eef2047-3b82-46b9-991b-a56f5ecb91fc")) {
#                     Plotly.newPlot(
#                         '8eef2047-3b82-46b9-991b-a56f5ecb91fc',
# ...

# %%
# 10 anos
t10 = web.DataReader('DGS10', 'fred', "2000-01-01")

# %%
px.line(data_frame=t10, x=t10.index, y='DGS10')
# Out:
# <div>
#
#
#             <div id="fc2572f7-2488-470e-8e5a-74c154805cdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fc2572f7-2488-470e-8e5a-74c154805cdb")) {
#                     Plotly.newPlot(
#                         'fc2572f7-2488-470e-8e5a-74c154805cdb',
# ...

# %%
# Taxa de desemprego
desemprego = web.DataReader('UNRATE', 'fred', "2000-01-01")

# %%
px.line(data_frame=desemprego, x=desemprego.index, y='UNRATE')
# Out:
# <div>
#
#
#             <div id="9704d2d6-8eed-4356-bc59-5e1a30e6945e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9704d2d6-8eed-4356-bc59-5e1a30e6945e")) {
#                     Plotly.newPlot(
#                         '9704d2d6-8eed-4356-bc59-5e1a30e6945e',
# ...

# %%
var_desemprego = desemprego.pct_change()[1:]

# %%
px.bar(data_frame=var_desemprego, x=var_desemprego.index, y='UNRATE')
# Out:
# <div>
#
#
#             <div id="6436dab3-57be-4c6b-83b1-7d37ba0c87a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6436dab3-57be-4c6b-83b1-7d37ba0c87a2")) {
#                     Plotly.newPlot(
#                         '6436dab3-57be-4c6b-83b1-7d37ba0c87a2',
# ...
